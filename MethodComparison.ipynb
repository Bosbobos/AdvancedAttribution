# %% [markdown]
# # Method Comparison
#
# Ноутбук-обёртка над `modules/MethodComparison.py`.
# Можно запускать отдельные сравнения или одним вызовом собрать текущие 4 таблицы в одну директорию и один markdown-файл.

# %%
from IPython.display import Markdown, display

from modules.MethodComparison import (
    compare_classifiers as _compare_classifiers_impl,
    compare_detectors as _compare_detectors_impl,
    export_current_notebook_tables as _export_current_notebook_tables_impl,
)

# %% [markdown]
# ## Параметры экспериментов

# %%
N_STEPS = 128

IMAGE_PATHS = [
    "data/jess.jpg",
    "data/umbrella_coco.jpg",
    "data/zebra_coco.png",
    "data/pizza_coco.jpg",
]

# %% [markdown]
# ## Отдельные Эксперименты

# %%
# res = compare_detectors(
#     image_paths=IMAGE_PATHS,
#     n_steps=N_STEPS,
#     mode="fixed_roi_mean",
#     layer_name="model.0",
#     roi_top_k=3,
# )

# res = compare_detectors(
#     image_paths=IMAGE_PATHS,
#     n_steps=N_STEPS,
#     mode="fixed_roi_mean",
#     layer_name="model.22",
#     roi_top_k=3,
# )

# res = compare_classifiers(
#     image_paths=IMAGE_PATHS,
#     n_steps=N_STEPS,
#     layer_name="model.0",
# )

# res = compare_classifiers(
#     image_paths=IMAGE_PATHS,
#     n_steps=N_STEPS,
#     layer_name="model.6",
# )

# %% [markdown]
# ## Общий Экспорт 4 Таблиц

# %%
res_all = export_current_notebook_tables(
    image_paths=IMAGE_PATHS,
    n_steps=N_STEPS,
)
# Out:
# ## Detectors, layer=model.0, mode=fixed_roi_mean
#
# | IG | NAA |
# | --- | --- |
# | ![](output/all_tables_steps_128_2/01_jess_5d717d0236_ig.png) | ![](output/all_tables_steps_128_2/01_jess_5e2dcad77a_naa.png) |
# | ![](output/all_tables_steps_128_2/02_umbrella_coco_19ccd0713d_ig.png) | ![](output/all_tables_steps_128_2/02_umbrella_coco_a6f5b6a8b4_naa.png) |
# | ![](output/all_tables_steps_128_2/03_zebra_coco_13aac0ad5c_ig.png) | ![](output/all_tables_steps_128_2/03_zebra_coco_6c54df17e3_naa.png) |
# | ![](output/all_tables_steps_128_2/04_pizza_coco_8558928417_ig.png) | ![](output/all_tables_steps_128_2/04_pizza_coco_88d99482e8_naa.png) |
#
# ## Detectors, layer=model.22, mode=fixed_roi_mean
#
# | IG | NAA |
# | --- | --- |
# | ![](output/all_tables_steps_128_2/01_jess_08e91b41ea_ig.png) | ![](output/all_tables_steps_128_2/01_jess_b8301a8388_naa.png) |
# | ![](output/all_tables_steps_128_2/02_umbrella_coco_186736dc8a_ig.png) | ![](output/all_tables_steps_128_2/02_umbrella_coco_efb6a14f6a_naa.png) |
# | ![](output/all_tables_steps_128_2/03_zebra_coco_c4046bd1b7_ig.png) | ![](output/all_tables_steps_128_2/03_zebra_coco_654c7ddc61_naa.png) |
# | ![](output/all_tables_steps_128_2/04_pizza_coco_a93e6b9088_ig.png) | ![](output/all_tables_steps_128_2/04_pizza_coco_6167871675_naa.png) |
#
# ## Classifiers, layer=model.0
#
# | IG | NAA |
# | --- | --- |
# | ![](output/all_tables_steps_128_2/01_jess_63356d6aa5_ig.png) | ![](output/all_tables_steps_128_2/01_jess_03cacfcee0_naa.png) |
# | ![](output/all_tables_steps_128_2/02_umbrella_coco_018b9e38b7_ig.png) | ![](output/all_tables_steps_128_2/02_umbrella_coco_9295f9c48a_naa.png) |
# | ![](output/all_tables_steps_128_2/03_zebra_coco_99f7acad0e_ig.png) | ![](output/all_tables_steps_128_2/03_zebra_coco_911e70308e_naa.png) |
# | ![](output/all_tables_steps_128_2/04_pizza_coco_8a3fe022a0_ig.png) | ![](output/all_tables_steps_128_2/04_pizza_coco_00b49be77a_naa.png) |
#
# ## Classifiers, layer=model.6
#
# | IG | NAA |
# | --- | --- |
# | ![](output/all_tables_steps_128_2/01_jess_fc35ff42b1_ig.png) | ![](output/all_tables_steps_128_2/01_jess_9de42f0388_naa.png) |
# | ![](output/all_tables_steps_128_2/02_umbrella_coco_ba1b1a86b3_ig.png) | ![](output/all_tables_steps_128_2/02_umbrella_coco_0a2e4c8fb1_naa.png) |
# | ![](output/all_tables_steps_128_2/03_zebra_coco_ad94a52001_ig.png) | ![](output/all_tables_steps_128_2/03_zebra_coco_4aa69a831d_naa.png) |
# | ![](output/all_tables_steps_128_2/04_pizza_coco_0766b3cb9b_ig.png) | ![](output/all_tables_steps_128_2/04_pizza_coco_810f5bec85_naa.png) |
# **Output Dir:** `/Users/ashentide/PycharmProjects/PaperImplementations/output/all_tables_steps_128_2`
# **Saved Markdown:** `/Users/ashentide/PycharmProjects/PaperImplementations/output/all_tables_steps_128_2/all_tables.md`
# ```md
# ## Detectors, layer=model.0, mode=fixed_roi_mean
#
# | IG | NAA |
# | --- | --- |
# | ![[01_jess_5d717d0236_ig.png]] | ![[01_jess_5e2dcad77a_naa.png]] |
# | ![[02_umbrella_coco_19ccd0713d_ig.png]] | ![[02_umbrella_coco_a6f5b6a8b4_naa.png]] |
# | ![[03_zebra_coco_13aac0ad5c_ig.png]] | ![[03_zebra_coco_6c54df17e3_naa.png]] |
# | ![[04_pizza_coco_8558928417_ig.png]] | ![[04_pizza_coco_88d99482e8_naa.png]] |
#
# ## Detectors, layer=model.22, mode=fixed_roi_mean
#
# | IG | NAA |
# | --- | --- |
# | ![[01_jess_08e91b41ea_ig.png]] | ![[01_jess_b8301a8388_naa.png]] |
# | ![[02_umbrella_coco_186736dc8a_ig.png]] | ![[02_umbrella_coco_efb6a14f6a_naa.png]] |
# | ![[03_zebra_coco_c4046bd1b7_ig.png]] | ![[03_zebra_coco_654c7ddc61_naa.png]] |
# | ![[04_pizza_coco_a93e6b9088_ig.png]] | ![[04_pizza_coco_6167871675_naa.png]] |
#
# ## Classifiers, layer=model.0
#
# | IG | NAA |
# | --- | --- |
# | ![[01_jess_63356d6aa5_ig.png]] | ![[01_jess_03cacfcee0_naa.png]] |
# | ![[02_umbrella_coco_018b9e38b7_ig.png]] | ![[02_umbrella_coco_9295f9c48a_naa.png]] |
# | ![[03_zebra_coco_99f7acad0e_ig.png]] | ![[03_zebra_coco_911e70308e_naa.png]] |
# | ![[04_pizza_coco_8a3fe022a0_ig.png]] | ![[04_pizza_coco_00b49be77a_naa.png]] |
#
# ## Classifiers, layer=model.6
#
# | IG | NAA |
# | --- | --- |
# | ![[01_jess_fc35ff42b1_ig.png]] | ![[01_jess_9de42f0388_naa.png]] |
# | ![[02_umbrella_coco_ba1b1a86b3_ig.png]] | ![[02_umbrella_coco_0a2e4c8fb1_naa.png]] |
# | ![[03_zebra_coco_ad94a52001_ig.png]] | ![[03_zebra_coco_4aa69a831d_naa.png]] |
# | ![[04_pizza_coco_0766b3cb9b_ig.png]] | ![[04_pizza_coco_810f5bec85_naa.png]] |
#
# ```
